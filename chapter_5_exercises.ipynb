# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/NLP/blob/main/chapter_5_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# __Exercise 1)__

# %%
#EYE DROPS OFF SHELF
# Correct: Eye(Noun) Drops(Noun Plural) off(Preposition) shelf(Noun)
# Misinterpretation: Eye(Noun) Drops(Verb) off(Preporsition) shelf(Noun)

# %% [markdown]
# __Exercise 2)__

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# True

# %%
import nltk
from nltk.corpus import brown
brown_tagged = brown.tagged_words(tagset='universal')
# word: contest, guess: noun
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_tagged if word == 'contest')
print(tag_fd.keys())
print(tag_fd['VERB'])
print(tag_fd['NOUN'])
# Out:
# dict_keys(['NOUN', 'VERB'])
# 2
# 22

# %%
# word: play, guess: verb
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_tagged if word == 'play')
print(tag_fd.keys())
print(tag_fd['VERB'])
print(tag_fd['NOUN'])
# Out:
# dict_keys(['VERB', 'NOUN'])
# 109
# 88

# %% [markdown]
# __Exercise 3)__

# %%
# (They, PRON) (wind, VERB) (back, ADP) (the, DET) (clock, NOUN)
# (while, CONJ) (we, PRON) (chase, VERB) (after, ADP) (the, DET) (wind, NOUN)
# => (wind, VERB) vs. (wind, NOUN)

# %% [markdown]
# __Exercise 4)__

# %%
# Pronunciation dictionary, maps from written form to phonetic transcriptions of possible pronunciations
# Syntax tree analyzer, maps from surface form of sentence to analyzed tree structure

# %% [markdown]
# __Exercise 5)__

# %%
d = {}
d['foo'] = 'bar'
d['baz'] = 123
d
# Out:
# {'foo': 'bar', 'baz': 123}

# %%
# d['xyz']

# %% [markdown]
# __Exercise 6)__

# %%
del d['foo']
d
# Out:
# {'baz': 123}

# %% [markdown]
# __Exercise 7)__

# %%
d1 = {'foo': 123, 'bar': 456}
d1 = {1: 'some entry', 'foo': 'something new'}
d1.update(d1)
print(d1)
##print(d2)
# Out:
# {1: 'some entry', 'foo': 'something new'}

# %%
# added entries from d2 to d1, updated entries in d1 if existing in d2
# useful e.g. for cases like default tagger fallback -> can create a default dict that can be updated with more sophisticated tagger

# %% [markdown]
# __Exercise 8)__

# %%
e = {'headword': 'piano', 'part-of-speech': 'NOUN', 'sense': 'a musical instrument with keys', 'example': 'She like to play pieces by Mozart on her piano.'}

# %%
e
# Out:
# {'headword': 'piano',
#  'part-of-speech': 'NOUN',
#  'sense': 'a musical instrument with keys',
#  'example': 'She like to play pieces by Mozart on her piano.'}

# %% [markdown]
# __Exercise 9)__

# %%
from nltk.text import Text
Text(brown.words()).concordance('go')
# Out:
# Displaying 25 of 626 matches:
# struction bonds . The bond issue will go to the state courts for a friendly te
# ress text still had `` quite a way to go '' toward completion . Decisions are
#  replied , `` I would say it's got to go thru several more drafts '' . Salinge
# ause the levy is already scheduled to go up by 1 per cent on that date to pay
# irst year , 1963 . Both figures would go higher in later years . Other parts o
# lion dollars the first year and would go up to 21 millions by 1966 . The Presi
# said yesterday he would be willing to go before the city council `` or anyone
# red would know what to do or where to go in the event of an enemy attack . The
# e another . Riverside residents would go to the Seekonk assembly point . Mr. H
# nk E. Smith as the one most likely to go , the redistricting battle will put t
# e battle . Then he could tell them to go home , while the administration conti
# pinion as to how far the board should go , and whose advice it should follow .
# n to where the parents wanted them to go . Dr. Melvin W. Barnes , superintende
# ay night in Salem . On Friday he will go to Portland for the swearing in of De
# `` Then we'd really have someplace to go '' . Bowie , Md. , March 17 -- Gainin
# `` Spahnie doesn't know how to merely go through the motions '' , remarked Eno
# Slocum Memorial Award . To Spahn will go the Sid Mercer Memorial Award as the
# ds . The writers' Gold Tee Award will go to John McAuliffe of Plainfield , N.
# ever , Mr. Parichy and his bride will go to Vero Beach on their wedding trip ,
# ncy '' . No matter how many Americans go abroad in summer , probably a hundred
# , service and comfort stations ( they go together like Scots and heather ) , d
# Werner said , was let manual laborers go home Tuesday night for some rest . Wo
# t destroyers . It could , reputedly , go 70,000 miles without refueling and st
# dinator of audio-visual education may go to the state Supreme Court , it appea
#  therefore knew them . It was time to go up myself '' . Fiedler was then techn

# %%
Text(brown.words()).concordance('went')
# Out:
# Displaying 25 of 507 matches:
# ade good his promise . `` Everything went real smooth '' , the sheriff said .
# axation . Under committee rules , it went automatically to a subcommittee for
# e . And after several correspondents went into Pathet Lao territory and expose
# the Kansas City scoring in the sixth went like this : Lumpe worked a walk as t
# his season to 13 straight before one went astray last Saturday night in the 41
# nd caught one pass for 13 yards . He went into the Army in March , 1957 , and
# m Monday , ran for 30 minutes , then went in , while the reserves scrimmaged f
# tchie of the Ogden Standard Examiner went to his compartment to talk with him
# pped into his second shot . The ball went off in a majestic arc , an out-of-bo
#  rare sense of humor . Everywhere he went in town , people sidled up , gave hi
# e is where a man was born , reared , went to school and , most particularly ,
#  off for good behavior . He promptly went to communist East Germany . The magi
# in the Skipjack . With the machinery went a complete design for the hull . The
# issile submarines '' , the statement went on . The atom reactor , water cooled
# e this account : Thomas early Sunday went to the home of his uncle and aunt ,
# sheep showman contest . Blue ribbons went to Stephanie Shaw of Hillsboro , Lar
# nks . Swine showmanship championship went to Bob Day , with Tom Day and Hutchi
# d on the jury . Then , when the case went to the jury , the judge excused one
# streamer of dust it landed . Fiedler went on to make several other test flight
# inals . Second grand prize of $5,000 went to Mrs. Clara L. Oliver for her Hawa
# Last two to be added before the book went to press were the marriages of Mered
#  next year's television shows . So I went to see `` La Dolce Vita '' . It has
# ou have language problems . The week went along briskly enough . I bought a ne
# eaded up one of the four groups that went on simultaneous tours after the Gall
# tings and sculptures to each group , went one of the Gallery's blue-uniformed

# %%
# 'go' appears after 'to', 'would', 'will', 'may' where 'went' cannot appear
# both can appear after pronouns/nouns

# %% [markdown]
# __Exercise 10)__

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
brown_tagged_sents = brown.tagged_sents()
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(nltk.word_tokenize('Villa Park is an association football stadium in Aston, Birmingham, England, with a seating capacity of 42,682. Formerly a sports ground in a Victorian amusement park, it has been the home of Aston Villa Football Club since 17 April 1897.'))
# Out:
# [('Villa', 'NP'),
#  ('Park', 'NN-TL'),
#  ('is', 'BEZ'),
#  ('an', 'AT'),
#  ('association', 'NN'),
#  ('football', 'NN'),
#  ('stadium', 'NN'),
#  ('in', 'IN'),
#  ('Aston', None),
#  (',', ','),
#  ('Birmingham', 'NP'),
#  (',', ','),
#  ('England', 'NP'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'AT'),
#  ('seating', 'VBG'),
#  ('capacity', 'NN'),
#  ('of', 'IN'),
#  ('42,682', None),
#  ('.', '.'),
#  ('Formerly', 'RB'),
#  ('a', 'AT'),
#  ('sports', 'NNS'),
#  ('ground', 'NN'),
#  ('in', 'IN'),
#  ('a', 'AT'),
#  ('Victorian', 'JJ'),
#  ('amusement', 'NN'),
#  ('park', 'NN'),
#  (',', ','),
#  ('it', 'PPS'),
#  ('has', 'HVZ'),
#  ('been', 'BEN'),
#  ('the', 'AT'),
#  ('home', 'NR'),
#  ('of', 'IN'),
#  ('Aston', None),
#  ('Villa', 'NP'),
#  ('Football', 'NN-TL'),
#  ('Club', 'NN-TL'),
#  ('since', 'CS'),
#  ('17', 'CD'),
#  ('April', 'NP'),
#  ('1897', 'CD'),
#  ('.', '.')]

# %%
# cannot tag words that it has not seen during training

# %% [markdown]
# __Exercise 11)__

# %%
help(nltk.AffixTagger)
# Out:
# Help on class AffixTagger in module nltk.tag.sequential:
#
# class AffixTagger(ContextTagger)
#  |  AffixTagger(train=None, model=None, affix_length=-3, min_stem_length=2, backoff=None, cutoff=0, verbose=False)
#  |
#  |  A tagger that chooses a token's tag based on a leading or trailing
#  |  substring of its word string.  (It is important to note that these
#  |  substrings are not necessarily "true" morphological affixes).  In
#  |  particular, a fixed-length substring of the word is looked up in a
#  |  table, and the corresponding tag is returned.  Affix taggers are
#  |  typically constructed by training them on a tagged corpus.
#  |
#  |  Construct a new affix tagger.
#  |
#  |  :param affix_length: The length of the affixes that should be
#  |      considered during training and tagging.  Use negative
#  |      numbers for suffixes.
#  |  :param min_stem_length: Any words whose length is less than
#  |      min_stem_length+abs(affix_length) will be assigned a
#  |      tag of None by this tagger.
#  |
#  |  Method resolution order:
#  |      AffixTagger
#  |      ContextTagger
#  |      SequentialBackoffTagger
#  |      nltk.tag.api.TaggerI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, train=None, model=None, affix_length=-3, min_stem_length=2, backoff=None, cutoff=0, verbose=False)
#  |      :param context_to_tag: A dictionary mapping contexts to tags.
#  |      :param backoff: The backoff tagger that should be used for this tagger.
#  |
#  |  context(self, tokens, index, history)
#  |      :return: the context that should be used to look up the tag
#  |          for the specified token; or None if the specified token
#  |          should not be handled by this tagger.
#  |      :rtype: (hashable)
#  |
#  |  encode_json_obj(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  decode_json_obj(obj) from abc.ABCMeta
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  json_tag = 'nltk.tag.sequential.AffixTagger'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ContextTagger:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  choose_tag(self, tokens, index, history)
#  |      Decide which tag should be used for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, return None -- do not consult
#  |      the backoff tagger.  This method should be overridden by
#  |      subclasses of SequentialBackoffTagger.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  size(self)
#  |      :return: The number of entries in the table used by this
#  |          tagger to map from contexts to tags.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from SequentialBackoffTagger:
#  |
#  |  tag(self, tokens)
#  |      Determine the most appropriate tag sequence for the given
#  |      token sequence, and return a corresponding list of tagged
#  |      tokens.  A tagged token is encoded as a tuple ``(token, tag)``.
#  |
#  |      :rtype: list(tuple(str, str))
#  |
#  |  tag_one(self, tokens, index, history)
#  |      Determine an appropriate tag for the specified token, and
#  |      return that tag.  If this tagger is unable to determine a tag
#  |      for the specified token, then its backoff tagger is consulted.
#  |
#  |      :rtype: str
#  |      :type tokens: list
#  |      :param tokens: The list of words that are being tagged.
#  |      :type index: int
#  |      :param index: The index of the word whose tag should be
#  |          returned.
#  |      :type history: list(str)
#  |      :param history: A list of the tags for all words before *index*.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from SequentialBackoffTagger:
#  |
#  |  backoff
#  |      The backoff tagger for this tagger.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from nltk.tag.api.TaggerI:
#  |
#  |  accuracy(self, gold)
#  |      Score the accuracy of the tagger against the gold standard.
#  |      Strip the tags from the gold standard text, retag it using
#  |      the tagger, then compute the accuracy score.
#  |
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :type gold: list(list(tuple(str, str)))
#  |      :rtype: float
#  |
#  |  confusion(self, gold)
#  |      Return a ConfusionMatrix with the tags from ``gold`` as the reference
#  |      values, with the predictions from ``tag_sents`` as the predicted values.
#  |
#  |      >>> from nltk.tag import PerceptronTagger
#  |      >>> from nltk.corpus import treebank
#  |      >>> tagger = PerceptronTagger()
#  |      >>> gold_data = treebank.tagged_sents()[:10]
#  |      >>> print(tagger.confusion(gold_data))
#  |             |        -                                                                                     |
#  |             |        N                                                                                     |
#  |             |        O                                               P                                     |
#  |             |        N                       J  J        N  N  P  P  R     R           V  V  V  V  V  W    |
#  |             |  '     E     C  C  D  E  I  J  J  J  M  N  N  N  O  R  P  R  B  R  T  V  B  B  B  B  B  D  ` |
#  |             |  '  ,  -  .  C  D  T  X  N  J  R  S  D  N  P  S  S  P  $  B  R  P  O  B  D  G  N  P  Z  T  ` |
#  |      -------+----------------------------------------------------------------------------------------------+
#  |          '' | <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |           , |  .<15> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |      -NONE- |  .  . <.> .  .  2  .  .  .  2  .  .  .  5  1  .  .  .  .  2  .  .  .  .  .  .  .  .  .  .  . |
#  |           . |  .  .  .<10> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          CC |  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          CD |  .  .  .  .  . <5> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          DT |  .  .  .  .  .  .<20> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          EX |  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          IN |  .  .  .  .  .  .  .  .<22> .  .  .  .  .  .  .  .  .  .  3  .  .  .  .  .  .  .  .  .  .  . |
#  |          JJ |  .  .  .  .  .  .  .  .  .<16> .  .  .  .  1  .  .  .  .  1  .  .  .  .  .  .  .  .  .  .  . |
#  |         JJR |  .  .  .  .  .  .  .  .  .  . <.> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |         JJS |  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          MD |  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |          NN |  .  .  .  .  .  .  .  .  .  .  .  .  .<28> 1  1  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |         NNP |  .  .  .  .  .  .  .  .  .  .  .  .  .  .<25> .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |         NNS |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .<19> .  .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |         POS |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |         PRP |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <4> .  .  .  .  .  .  .  .  .  .  .  .  . |
#  |        PRP$ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <2> .  .  .  .  .  .  .  .  .  .  .  . |
#  |          RB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <4> .  .  .  .  .  .  .  .  .  .  . |
#  |         RBR |  .  .  .  .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  .  . |
#  |          RP |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1> .  .  .  .  .  .  .  .  . |
#  |          TO |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <5> .  .  .  .  .  .  .  . |
#  |          VB |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  .  .  .  .  . |
#  |         VBD |  .  .  .  .  .  .  .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  .  . <6> .  .  .  .  .  . |
#  |         VBG |  .  .  .  .  .  .  .  .  .  .  .  .  .  1  .  .  .  .  .  .  .  .  .  .  . <4> .  .  .  .  . |
#  |         VBN |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  1  . <4> .  .  .  . |
#  |         VBP |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <3> .  .  . |
#  |         VBZ |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <7> .  . |
#  |         WDT |  .  .  .  .  .  .  .  .  2  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <.> . |
#  |          `` |  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  . <1>|
#  |      -------+----------------------------------------------------------------------------------------------+
#  |      (row = reference; col = test)
#  |      <BLANKLINE>
#  |
#  |      :param gold: The list of tagged sentences to run the tagger with,
#  |          also used as the reference values in the generated confusion matrix.
#  |      :type gold: list(list(tuple(str, str)))
#  |      :rtype: ConfusionMatrix
#  |
#  |  evaluate(*args, **kwargs)
#  |      @deprecated: Use accuracy(gold) instead.
#  |
#  |  evaluate_per_tag(self, gold, alpha=0.5, truncate=None, sort_by_count=False)
#  |      Tabulate the **recall**, **precision** and **f-measure**
#  |      for each tag from ``gold`` or from running ``tag`` on the tokenized
#  |      sentences from ``gold``.
#  |
#  |      >>> from nltk.tag import PerceptronTagger
#  |      >>> from nltk.corpus import treebank
#  |      >>> tagger = PerceptronTagger()
#  |      >>> gold_data = treebank.tagged_sents()[:10]
#  |      >>> print(tagger.evaluate_per_tag(gold_data))
#  |         Tag | Prec.  | Recall | F-measure
#  |      -------+--------+--------+-----------
#  |          '' | 1.0000 | 1.0000 | 1.0000
#  |           , | 1.0000 | 1.0000 | 1.0000
#  |      -NONE- | 0.0000 | 0.0000 | 0.0000
#  |           . | 1.0000 | 1.0000 | 1.0000
#  |          CC | 1.0000 | 1.0000 | 1.0000
#  |          CD | 0.7143 | 1.0000 | 0.8333
#  |          DT | 1.0000 | 1.0000 | 1.0000
#  |          EX | 1.0000 | 1.0000 | 1.0000
#  |          IN | 0.9167 | 0.8800 | 0.8980
#  |          JJ | 0.8889 | 0.8889 | 0.8889
#  |         JJR | 0.0000 | 0.0000 | 0.0000
#  |         JJS | 1.0000 | 1.0000 | 1.0000
#  |          MD | 1.0000 | 1.0000 | 1.0000
#  |          NN | 0.8000 | 0.9333 | 0.8615
#  |         NNP | 0.8929 | 1.0000 | 0.9434
#  |         NNS | 0.9500 | 1.0000 | 0.9744
#  |         POS | 1.0000 | 1.0000 | 1.0000
#  |         PRP | 1.0000 | 1.0000 | 1.0000
#  |        PRP$ | 1.0000 | 1.0000 | 1.0000
#  |          RB | 0.4000 | 1.0000 | 0.5714
#  |         RBR | 1.0000 | 0.5000 | 0.6667
#  |          RP | 1.0000 | 1.0000 | 1.0000
#  |          TO | 1.0000 | 1.0000 | 1.0000
#  |          VB | 1.0000 | 1.0000 | 1.0000
#  |         VBD | 0.8571 | 0.8571 | 0.8571
#  |         VBG | 1.0000 | 0.8000 | 0.8889
#  |         VBN | 1.0000 | 0.8000 | 0.8889
#  |         VBP | 1.0000 | 1.0000 | 1.0000
#  |         VBZ | 1.0000 | 1.0000 | 1.0000
#  |         WDT | 0.0000 | 0.0000 | 0.0000
#  |          `` | 1.0000 | 1.0000 | 1.0000
#  |      <BLANKLINE>
#  |
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :type gold: list(list(tuple(str, str)))
#  |      :param alpha: Ratio of the cost of false negative compared to false
#  |          positives, as used in the f-measure computation. Defaults to 0.5,
#  |          where the costs are equal.
#  |      :type alpha: float
#  |      :param truncate: If specified, then only show the specified
#  |          number of values.  Any sorting (e.g., sort_by_count)
#  |          will be performed before truncation. Defaults to None
#  |      :type truncate: int, optional
#  |      :param sort_by_count: Whether to sort the outputs on number of
#  |          occurrences of that tag in the ``gold`` data, defaults to False
#  |      :type sort_by_count: bool, optional
#  |      :return: A tabulated recall, precision and f-measure string
#  |      :rtype: str
#  |
#  |  f_measure(self, gold, alpha=0.5)
#  |      Compute the f-measure for each tag from ``gold`` or from running ``tag``
#  |      on the tokenized sentences from ``gold``. Then, return the dictionary
#  |      with mappings from tag to f-measure. The f-measure is the harmonic mean
#  |      of the ``precision`` and ``recall``, weighted by ``alpha``.
#  |      In particular, given the precision *p* and recall *r* defined by:
#  |
#  |      - *p* = true positive / (true positive + false negative)
#  |      - *r* = true positive / (true positive + false positive)
#  |
#  |      The f-measure is:
#  |
#  |      - *1/(alpha/p + (1-alpha)/r)*
#  |
#  |      With ``alpha = 0.5``, this reduces to:
#  |
#  |      - *2pr / (p + r)*
#  |
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :type gold: list(list(tuple(str, str)))
#  |      :param alpha: Ratio of the cost of false negative compared to false
#  |          positives. Defaults to 0.5, where the costs are equal.
#  |      :type alpha: float
#  |      :return: A mapping from tags to precision
#  |      :rtype: Dict[str, float]
#  |
#  |  precision(self, gold)
#  |      Compute the precision for each tag from ``gold`` or from running ``tag``
#  |      on the tokenized sentences from ``gold``. Then, return the dictionary
#  |      with mappings from tag to precision. The precision is defined as:
#  |
#  |      - *p* = true positive / (true positive + false negative)
#  |
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :type gold: list(list(tuple(str, str)))
#  |      :return: A mapping from tags to precision
#  |      :rtype: Dict[str, float]
#  |
#  |  recall(self, gold) -> Dict[str, float]
#  |      Compute the recall for each tag from ``gold`` or from running ``tag``
#  |      on the tokenized sentences from ``gold``. Then, return the dictionary
#  |      with mappings from tag to recall. The recall is defined as:
#  |
#  |      - *r* = true positive / (true positive + false positive)
#  |
#  |      :param gold: The list of tagged sentences to score the tagger on.
#  |      :type gold: list(list(tuple(str, str)))
#  |      :return: A mapping from tags to recall
#  |      :rtype: Dict[str, float]
#  |
#  |  tag_sents(self, sentences)
#  |      Apply ``self.tag()`` to each element of *sentences*.  I.e.::
#  |
#  |          return [self.tag(sent) for sent in sentences]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from nltk.tag.api.TaggerI:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
affix_tagger = nltk.AffixTagger(brown_tagged_sents, affix_length=3, min_stem_length=1)
affix_tagger.tag(nltk.word_tokenize('The Road to Emmaus appearance is one of the early resurrection appearances of Jesus after his crucifixion and the discovery of the empty tomb. Both the Meeting on the road to Emmaus and the subsequent Supper at Emmaus, depicting the meal that Jesus had with two disciples after the encounter on the road, have been popular subjects in art.'))
# Out:
# [('The', None),
#  ('Road', 'NN-TL'),
#  ('to', None),
#  ('Emmaus', 'NP'),
#  ('appearance', 'NN'),
#  ('is', None),
#  ('one', None),
#  ('of', None),
#  ('the', None),
#  ('early', 'JJ'),
#  ('resurrection', 'NN'),
#  ('appearances', 'NN'),
#  ('of', None),
#  ('Jesus', 'NP'),
#  ('after', 'IN'),
#  ('his', None),
#  ('crucifixion', 'JJ'),
#  ('and', None),
#  ('the', None),
#  ('discovery', 'NN'),
#  ('of', None),
#  ('the', None),
#  ('empty', 'NN'),
#  ('tomb', 'NR'),
#  ('.', None),
#  ('Both', 'ABX'),
#  ('the', None),
#  ('Meeting', 'NP'),
#  ('on', None),
#  ('the', None),
#  ('road', 'NN'),
#  ('to', None),
#  ('Emmaus', 'NP'),
#  ('and', None),
#  ('the', None),
#  ('subsequent', 'NN'),
#  ('Supper', 'JJ-TL'),
#  ('at', None),
#  ('Emmaus', 'NP'),
#  (',', None),
#  ('depicting', 'NN'),
#  ('the', None),
#  ('meal', 'NN'),
#  ('that', 'CS'),
#  ('Jesus', 'NP'),
#  ('had', None),
#  ('with', 'IN'),
#  ('two', None),
#  ('disciples', 'NN'),
#  ('after', 'IN'),
#  ('the', None),
#  ('encounter', 'VB'),
#  ('on', None),
#  ('the', None),
#  ('road', 'NN'),
#  (',', None),
#  ('have', 'HV'),
#  ('been', 'BEN'),
#  ('popular', 'NN'),
#  ('subjects', 'NN'),
#  ('in', None),
#  ('art', None),
#  ('.', None)]

# %%
# does well on nouns with typical endings
affix_tagger = nltk.AffixTagger(brown_tagged_sents, affix_length=2, min_stem_length=0)
affix_tagger.tag(nltk.word_tokenize('The Road to Emmaus appearance is one of the early resurrection appearances of Jesus after his crucifixion and the discovery of the empty tomb. Both the Meeting on the road to Emmaus and the subsequent Supper at Emmaus, depicting the meal that Jesus had with two disciples after the encounter on the road, have been popular subjects in art.'))
# Out:
# [('The', 'AT'),
#  ('Road', 'NP'),
#  ('to', 'TO'),
#  ('Emmaus', 'NN-TL'),
#  ('appearance', 'NN'),
#  ('is', 'BEZ'),
#  ('one', 'IN'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('early', 'DT'),
#  ('resurrection', 'NN'),
#  ('appearances', 'NN'),
#  ('of', 'IN'),
#  ('Jesus', 'NP'),
#  ('after', 'IN'),
#  ('his', 'PP$'),
#  ('crucifixion', 'NN'),
#  ('and', 'CC'),
#  ('the', 'AT'),
#  ('discovery', 'NN'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('empty', 'NN'),
#  ('tomb', 'TO'),
#  ('.', None),
#  ('Both', 'NP'),
#  ('the', 'AT'),
#  ('Meeting', 'NP'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('road', 'NN'),
#  ('to', 'TO'),
#  ('Emmaus', 'NN-TL'),
#  ('and', 'CC'),
#  ('the', 'AT'),
#  ('subsequent', 'JJ'),
#  ('Supper', 'NP'),
#  ('at', 'IN'),
#  ('Emmaus', 'NN-TL'),
#  (',', None),
#  ('depicting', 'NN'),
#  ('the', 'AT'),
#  ('meal', 'NNS'),
#  ('that', 'AT'),
#  ('Jesus', 'NP'),
#  ('had', 'HVD'),
#  ('with', 'IN'),
#  ('two', 'CD'),
#  ('disciples', 'NN'),
#  ('after', 'IN'),
#  ('the', 'AT'),
#  ('encounter', 'NN'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('road', 'NN'),
#  (',', None),
#  ('have', 'HVD'),
#  ('been', 'BE'),
#  ('popular', 'NN'),
#  ('subjects', 'JJ'),
#  ('in', 'IN'),
#  ('art', 'BER'),
#  ('.', None)]

# %% [markdown]
# __Exercise 12)__

# %%
bigram_tagger = nltk.BigramTagger(brown_tagged_sents)

# %%
bigram_tagger.tag(brown.sents()[0])
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBN'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'WPS'),
#  ('any', None),
#  ('irregularities', None),
#  ('took', None),
#  ('place', None),
#  ('.', None)]

# %%
bigram_tagger.tag(nltk.word_tokenize('The Road to Emmaus appearance is one of the early resurrection appearances of Jesus after his crucifixion and the discovery of the empty tomb. Both the Meeting on the road to Emmaus and the subsequent Supper at Emmaus, depicting the meal that Jesus had with two disciples after the encounter on the road, have been popular subjects in art.'))
# Out:
# [('The', 'AT'),
#  ('Road', None),
#  ('to', None),
#  ('Emmaus', None),
#  ('appearance', None),
#  ('is', None),
#  ('one', None),
#  ('of', None),
#  ('the', None),
#  ('early', None),
#  ('resurrection', None),
#  ('appearances', None),
#  ('of', None),
#  ('Jesus', None),
#  ('after', None),
#  ('his', None),
#  ('crucifixion', None),
#  ('and', None),
#  ('the', None),
#  ('discovery', None),
#  ('of', None),
#  ('the', None),
#  ('empty', None),
#  ('tomb', None),
#  ('.', None),
#  ('Both', None),
#  ('the', None),
#  ('Meeting', None),
#  ('on', None),
#  ('the', None),
#  ('road', None),
#  ('to', None),
#  ('Emmaus', None),
#  ('and', None),
#  ('the', None),
#  ('subsequent', None),
#  ('Supper', None),
#  ('at', None),
#  ('Emmaus', None),
#  (',', None),
#  ('depicting', None),
#  ('the', None),
#  ('meal', None),
#  ('that', None),
#  ('Jesus', None),
#  ('had', None),
#  ('with', None),
#  ('two', None),
#  ('disciples', None),
#  ('after', None),
#  ('the', None),
#  ('encounter', None),
#  ('on', None),
#  ('the', None),
#  ('road', None),
#  (',', None),
#  ('have', None),
#  ('been', None),
#  ('popular', None),
#  ('subjects', None),
#  ('in', None),
#  ('art', None),
#  ('.', None)]

# %%
# performs very badly on unseen data -> once it sees 'None' tag, cannot tag the rest because in training it hasn't seen bigrams with 'None'

# %% [markdown]
# __Exercise 13)__

# %%
date_dict = {'day': '22', 'month': 'April', 'month_num': '04', 'year': '2017'}
print('{day} of {month}, {year}.'.format(**date_dict))
print('{month_num}/{day}/{year}'.format(**date_dict))
# Out:
# 22 of April, 2017.
# 04/22/2017

# %% [markdown]
# __Exercise 14)__

# %%
tags = []
for sent in brown_tagged_sents:
    for (word, tag) in sent:
        tags.append(tag)

sorted(set(tags))
# Out:
# ["'",
#  "''",
#  '(',
#  '(-HL',
#  ')',
#  ')-HL',
#  '*',
#  '*-HL',
#  '*-NC',
#  '*-TL',
#  ',',
#  ',-HL',
#  ',-NC',
#  ',-TL',
#  '--',
#  '---HL',
#  '.',
#  '.-HL',
#  '.-NC',
#  '.-TL',
#  ':',
#  ':-HL',
#  ':-TL',
#  'ABL',
#  'ABN',
#  'ABN-HL',
#  'ABN-NC',
#  'ABN-TL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP+AP-NC',
#  'AP-HL',
#  'AP-NC',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-NC',
#  'AT-TL',
#  'AT-TL-HL',
#  'BE',
#  'BE-HL',
#  'BE-TL',
#  'BED',
#  'BED*',
#  'BED-NC',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEDZ-NC',
#  'BEG',
#  'BEM',
#  'BEM*',
#  'BEM-NC',
#  'BEN',
#  'BEN-TL',
#  'BER',
#  'BER*',
#  'BER*-NC',
#  'BER-HL',
#  'BER-NC',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'BEZ-NC',
#  'BEZ-TL',
#  'CC',
#  'CC-HL',
#  'CC-NC',
#  'CC-TL',
#  'CC-TL-HL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-NC',
#  'CD-TL',
#  'CD-TL-HL',
#  'CS',
#  'CS-HL',
#  'CS-NC',
#  'CS-TL',
#  'DO',
#  'DO*',
#  'DO*-HL',
#  'DO+PPSS',
#  'DO-HL',
#  'DO-NC',
#  'DO-TL',
#  'DOD',
#  'DOD*',
#  'DOD*-TL',
#  'DOD-NC',
#  'DOZ',
#  'DOZ*',
#  'DOZ*-TL',
#  'DOZ-HL',
#  'DOZ-TL',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT+BEZ-NC',
#  'DT+MD',
#  'DT-HL',
#  'DT-NC',
#  'DT-TL',
#  'DTI',
#  'DTI-HL',
#  'DTI-TL',
#  'DTS',
#  'DTS+BEZ',
#  'DTS-HL',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'EX+HVD',
#  'EX+HVZ',
#  'EX+MD',
#  'EX-HL',
#  'EX-NC',
#  'FW-*',
#  'FW-*-TL',
#  'FW-AT',
#  'FW-AT+NN-TL',
#  'FW-AT+NP-TL',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-BE',
#  'FW-BER',
#  'FW-BEZ',
#  'FW-CC',
#  'FW-CC-TL',
#  'FW-CD',
#  'FW-CD-TL',
#  'FW-CS',
#  'FW-DT',
#  'FW-DT+BEZ',
#  'FW-DTS',
#  'FW-HV',
#  'FW-IN',
#  'FW-IN+AT',
#  'FW-IN+AT-T',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN+NP-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-NC',
#  'FW-JJ-TL',
#  'FW-JJR',
#  'FW-JJT',
#  'FW-NN',
#  'FW-NN$',
#  'FW-NN$-TL',
#  'FW-NN-NC',
#  'FW-NN-TL',
#  'FW-NN-TL-NC',
#  'FW-NNS',
#  'FW-NNS-NC',
#  'FW-NNS-TL',
#  'FW-NP',
#  'FW-NP-TL',
#  'FW-NPS',
#  'FW-NPS-TL',
#  'FW-NR',
#  'FW-NR-TL',
#  'FW-OD-NC',
#  'FW-OD-TL',
#  'FW-PN',
#  'FW-PP$',
#  'FW-PP$-NC',
#  'FW-PP$-TL',
#  'FW-PPL',
#  'FW-PPL+VBZ',
#  'FW-PPO',
#  'FW-PPO+IN',
#  'FW-PPS',
#  'FW-PPSS',
#  'FW-PPSS+HV',
#  'FW-QL',
#  'FW-RB',
#  'FW-RB+CC',
#  'FW-RB-TL',
#  'FW-TO+VB',
#  'FW-UH',
#  'FW-UH-NC',
#  'FW-UH-TL',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-VB-TL',
#  'FW-VBD',
#  'FW-VBD-TL',
#  'FW-VBG',
#  'FW-VBG-TL',
#  'FW-VBN',
#  'FW-VBZ',
#  'FW-WDT',
#  'FW-WPO',
#  'FW-WPS',
#  'HV',
#  'HV*',
#  'HV+TO',
#  'HV-HL',
#  'HV-NC',
#  'HV-TL',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVG-HL',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'HVZ-NC',
#  'HVZ-TL',
#  'IN',
#  'IN+IN',
#  'IN+PPO',
#  'IN-HL',
#  'IN-NC',
#  'IN-TL',
#  'IN-TL-HL',
#  'JJ',
#  'JJ$-TL',
#  'JJ+JJ-NC',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJ-TL-HL',
#  'JJ-TL-NC',
#  'JJR',
#  'JJR+CS',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-HL',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'JJT-NC',
#  'JJT-TL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD+PPSS',
#  'MD+TO',
#  'MD-HL',
#  'MD-NC',
#  'MD-TL',
#  'NIL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN+BEZ',
#  'NN+BEZ-TL',
#  'NN+HVD-TL',
#  'NN+HVZ',
#  'NN+HVZ-TL',
#  'NN+IN',
#  'NN+MD',
#  'NN+NN-NC',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NN-TL-NC',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-NC',
#  'NNS$-TL',
#  'NNS$-TL-HL',
#  'NNS+MD',
#  'NNS-HL',
#  'NNS-NC',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NNS-TL-NC',
#  'NP',
#  'NP$',
#  'NP$-HL',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP+BEZ-NC',
#  'NP+HVZ',
#  'NP+HVZ-NC',
#  'NP+MD',
#  'NP-HL',
#  'NP-NC',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-HL',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-NC',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR+MD',
#  'NR-HL',
#  'NR-NC',
#  'NR-TL',
#  'NR-TL-HL',
#  'NRS',
#  'NRS-TL',
#  'OD',
#  'OD-HL',
#  'OD-NC',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+BEZ',
#  'PN+HVD',
#  'PN+HVZ',
#  'PN+MD',
#  'PN-HL',
#  'PN-NC',
#  'PN-TL',
#  'PP$',
#  'PP$$',
#  'PP$-HL',
#  'PP$-NC',
#  'PP$-TL',
#  'PPL',
#  'PPL-HL',
#  'PPL-NC',
#  'PPL-TL',
#  'PPLS',
#  'PPO',
#  'PPO-HL',
#  'PPO-NC',
#  'PPO-TL',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+BEZ-NC',
#  'PPS+HVD',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPS-HL',
#  'PPS-NC',
#  'PPS-TL',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+BER-N',
#  'PPSS+BER-NC',
#  'PPSS+BER-TL',
#  'PPSS+BEZ',
#  'PPSS+BEZ*',
#  'PPSS+HV',
#  'PPSS+HV-TL',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS+MD-NC',
#  'PPSS+VB',
#  'PPSS-HL',
#  'PPSS-NC',
#  'PPSS-TL',
#  'QL',
#  'QL-HL',
#  'QL-NC',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB+BEZ-HL',
#  'RB+BEZ-NC',
#  'RB+CS',
#  'RB-HL',
#  'RB-NC',
#  'RB-TL',
#  'RBR',
#  'RBR+CS',
#  'RBR-NC',
#  'RBT',
#  'RN',
#  'RP',
#  'RP+IN',
#  'RP-HL',
#  'RP-NC',
#  'RP-TL',
#  'TO',
#  'TO+VB',
#  'TO-HL',
#  'TO-NC',
#  'TO-TL',
#  'UH',
#  'UH-HL',
#  'UH-NC',
#  'UH-TL',
#  'VB',
#  'VB+AT',
#  'VB+IN',
#  'VB+JJ-NC',
#  'VB+PPO',
#  'VB+RP',
#  'VB+TO',
#  'VB+VB-NC',
#  'VB-HL',
#  'VB-NC',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-NC',
#  'VBD-TL',
#  'VBG',
#  'VBG+TO',
#  'VBG-HL',
#  'VBG-NC',
#  'VBG-TL',
#  'VBN',
#  'VBN+TO',
#  'VBN-HL',
#  'VBN-NC',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBN-TL-NC',
#  'VBZ',
#  'VBZ-HL',
#  'VBZ-NC',
#  'VBZ-TL',
#  'WDT',
#  'WDT+BER',
#  'WDT+BER+PP',
#  'WDT+BEZ',
#  'WDT+BEZ-HL',
#  'WDT+BEZ-NC',
#  'WDT+BEZ-TL',
#  'WDT+DO+PPS',
#  'WDT+DOD',
#  'WDT+HVZ',
#  'WDT-HL',
#  'WDT-NC',
#  'WP$',
#  'WPO',
#  'WPO-NC',
#  'WPO-TL',
#  'WPS',
#  'WPS+BEZ',
#  'WPS+BEZ-NC',
#  'WPS+BEZ-TL',
#  'WPS+HVD',
#  'WPS+HVZ',
#  'WPS+MD',
#  'WPS-HL',
#  'WPS-NC',
#  'WPS-TL',
#  'WQL',
#  'WQL-TL',
#  'WRB',
#  'WRB+BER',
#  'WRB+BEZ',
#  'WRB+BEZ-TL',
#  'WRB+DO',
#  'WRB+DOD',
#  'WRB+DOD*',
#  'WRB+DOZ',
#  'WRB+IN',
#  'WRB+MD',
#  'WRB-HL',
#  'WRB-NC',
#  'WRB-TL',
#  '``']

# %%
# shorter with list comprehension:
sorted(set(tag for sent in brown_tagged_sents for (word, tag) in sent))
# Out:
# ["'",
#  "''",
#  '(',
#  '(-HL',
#  ')',
#  ')-HL',
#  '*',
#  '*-HL',
#  '*-NC',
#  '*-TL',
#  ',',
#  ',-HL',
#  ',-NC',
#  ',-TL',
#  '--',
#  '---HL',
#  '.',
#  '.-HL',
#  '.-NC',
#  '.-TL',
#  ':',
#  ':-HL',
#  ':-TL',
#  'ABL',
#  'ABN',
#  'ABN-HL',
#  'ABN-NC',
#  'ABN-TL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP+AP-NC',
#  'AP-HL',
#  'AP-NC',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-NC',
#  'AT-TL',
#  'AT-TL-HL',
#  'BE',
#  'BE-HL',
#  'BE-TL',
#  'BED',
#  'BED*',
#  'BED-NC',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEDZ-NC',
#  'BEG',
#  'BEM',
#  'BEM*',
#  'BEM-NC',
#  'BEN',
#  'BEN-TL',
#  'BER',
#  'BER*',
#  'BER*-NC',
#  'BER-HL',
#  'BER-NC',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'BEZ-NC',
#  'BEZ-TL',
#  'CC',
#  'CC-HL',
#  'CC-NC',
#  'CC-TL',
#  'CC-TL-HL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-NC',
#  'CD-TL',
#  'CD-TL-HL',
#  'CS',
#  'CS-HL',
#  'CS-NC',
#  'CS-TL',
#  'DO',
#  'DO*',
#  'DO*-HL',
#  'DO+PPSS',
#  'DO-HL',
#  'DO-NC',
#  'DO-TL',
#  'DOD',
#  'DOD*',
#  'DOD*-TL',
#  'DOD-NC',
#  'DOZ',
#  'DOZ*',
#  'DOZ*-TL',
#  'DOZ-HL',
#  'DOZ-TL',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT+BEZ-NC',
#  'DT+MD',
#  'DT-HL',
#  'DT-NC',
#  'DT-TL',
#  'DTI',
#  'DTI-HL',
#  'DTI-TL',
#  'DTS',
#  'DTS+BEZ',
#  'DTS-HL',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'EX+HVD',
#  'EX+HVZ',
#  'EX+MD',
#  'EX-HL',
#  'EX-NC',
#  'FW-*',
#  'FW-*-TL',
#  'FW-AT',
#  'FW-AT+NN-TL',
#  'FW-AT+NP-TL',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-BE',
#  'FW-BER',
#  'FW-BEZ',
#  'FW-CC',
#  'FW-CC-TL',
#  'FW-CD',
#  'FW-CD-TL',
#  'FW-CS',
#  'FW-DT',
#  'FW-DT+BEZ',
#  'FW-DTS',
#  'FW-HV',
#  'FW-IN',
#  'FW-IN+AT',
#  'FW-IN+AT-T',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN+NP-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-NC',
#  'FW-JJ-TL',
#  'FW-JJR',
#  'FW-JJT',
#  'FW-NN',
#  'FW-NN$',
#  'FW-NN$-TL',
#  'FW-NN-NC',
#  'FW-NN-TL',
#  'FW-NN-TL-NC',
#  'FW-NNS',
#  'FW-NNS-NC',
#  'FW-NNS-TL',
#  'FW-NP',
#  'FW-NP-TL',
#  'FW-NPS',
#  'FW-NPS-TL',
#  'FW-NR',
#  'FW-NR-TL',
#  'FW-OD-NC',
#  'FW-OD-TL',
#  'FW-PN',
#  'FW-PP$',
#  'FW-PP$-NC',
#  'FW-PP$-TL',
#  'FW-PPL',
#  'FW-PPL+VBZ',
#  'FW-PPO',
#  'FW-PPO+IN',
#  'FW-PPS',
#  'FW-PPSS',
#  'FW-PPSS+HV',
#  'FW-QL',
#  'FW-RB',
#  'FW-RB+CC',
#  'FW-RB-TL',
#  'FW-TO+VB',
#  'FW-UH',
#  'FW-UH-NC',
#  'FW-UH-TL',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-VB-TL',
#  'FW-VBD',
#  'FW-VBD-TL',
#  'FW-VBG',
#  'FW-VBG-TL',
#  'FW-VBN',
#  'FW-VBZ',
#  'FW-WDT',
#  'FW-WPO',
#  'FW-WPS',
#  'HV',
#  'HV*',
#  'HV+TO',
#  'HV-HL',
#  'HV-NC',
#  'HV-TL',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVG-HL',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'HVZ-NC',
#  'HVZ-TL',
#  'IN',
#  'IN+IN',
#  'IN+PPO',
#  'IN-HL',
#  'IN-NC',
#  'IN-TL',
#  'IN-TL-HL',
#  'JJ',
#  'JJ$-TL',
#  'JJ+JJ-NC',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJ-TL-HL',
#  'JJ-TL-NC',
#  'JJR',
#  'JJR+CS',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-HL',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'JJT-NC',
#  'JJT-TL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD+PPSS',
#  'MD+TO',
#  'MD-HL',
#  'MD-NC',
#  'MD-TL',
#  'NIL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN+BEZ',
#  'NN+BEZ-TL',
#  'NN+HVD-TL',
#  'NN+HVZ',
#  'NN+HVZ-TL',
#  'NN+IN',
#  'NN+MD',
#  'NN+NN-NC',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NN-TL-NC',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-NC',
#  'NNS$-TL',
#  'NNS$-TL-HL',
#  'NNS+MD',
#  'NNS-HL',
#  'NNS-NC',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NNS-TL-NC',
#  'NP',
#  'NP$',
#  'NP$-HL',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP+BEZ-NC',
#  'NP+HVZ',
#  'NP+HVZ-NC',
#  'NP+MD',
#  'NP-HL',
#  'NP-NC',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-HL',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-NC',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR+MD',
#  'NR-HL',
#  'NR-NC',
#  'NR-TL',
#  'NR-TL-HL',
#  'NRS',
#  'NRS-TL',
#  'OD',
#  'OD-HL',
#  'OD-NC',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+BEZ',
#  'PN+HVD',
#  'PN+HVZ',
#  'PN+MD',
#  'PN-HL',
#  'PN-NC',
#  'PN-TL',
#  'PP$',
#  'PP$$',
#  'PP$-HL',
#  'PP$-NC',
#  'PP$-TL',
#  'PPL',
#  'PPL-HL',
#  'PPL-NC',
#  'PPL-TL',
#  'PPLS',
#  'PPO',
#  'PPO-HL',
#  'PPO-NC',
#  'PPO-TL',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+BEZ-NC',
#  'PPS+HVD',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPS-HL',
#  'PPS-NC',
#  'PPS-TL',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+BER-N',
#  'PPSS+BER-NC',
#  'PPSS+BER-TL',
#  'PPSS+BEZ',
#  'PPSS+BEZ*',
#  'PPSS+HV',
#  'PPSS+HV-TL',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS+MD-NC',
#  'PPSS+VB',
#  'PPSS-HL',
#  'PPSS-NC',
#  'PPSS-TL',
#  'QL',
#  'QL-HL',
#  'QL-NC',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB+BEZ-HL',
#  'RB+BEZ-NC',
#  'RB+CS',
#  'RB-HL',
#  'RB-NC',
#  'RB-TL',
#  'RBR',
#  'RBR+CS',
#  'RBR-NC',
#  'RBT',
#  'RN',
#  'RP',
#  'RP+IN',
#  'RP-HL',
#  'RP-NC',
#  'RP-TL',
#  'TO',
#  'TO+VB',
#  'TO-HL',
#  'TO-NC',
#  'TO-TL',
#  'UH',
#  'UH-HL',
#  'UH-NC',
#  'UH-TL',
#  'VB',
#  'VB+AT',
#  'VB+IN',
#  'VB+JJ-NC',
#  'VB+PPO',
#  'VB+RP',
#  'VB+TO',
#  'VB+VB-NC',
#  'VB-HL',
#  'VB-NC',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-NC',
#  'VBD-TL',
#  'VBG',
#  'VBG+TO',
#  'VBG-HL',
#  'VBG-NC',
#  'VBG-TL',
#  'VBN',
#  'VBN+TO',
#  'VBN-HL',
#  'VBN-NC',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBN-TL-NC',
#  'VBZ',
#  'VBZ-HL',
#  'VBZ-NC',
#  'VBZ-TL',
#  'WDT',
#  'WDT+BER',
#  'WDT+BER+PP',
#  'WDT+BEZ',
#  'WDT+BEZ-HL',
#  'WDT+BEZ-NC',
#  'WDT+BEZ-TL',
#  'WDT+DO+PPS',
#  'WDT+DOD',
#  'WDT+HVZ',
#  'WDT-HL',
#  'WDT-NC',
#  'WP$',
#  'WPO',
#  'WPO-NC',
#  'WPO-TL',
#  'WPS',
#  'WPS+BEZ',
#  'WPS+BEZ-NC',
#  'WPS+BEZ-TL',
#  'WPS+HVD',
#  'WPS+HVZ',
#  'WPS+MD',
#  'WPS-HL',
#  'WPS-NC',
#  'WPS-TL',
#  'WQL',
#  'WQL-TL',
#  'WRB',
#  'WRB+BER',
#  'WRB+BEZ',
#  'WRB+BEZ-TL',
#  'WRB+DO',
#  'WRB+DOD',
#  'WRB+DOD*',
#  'WRB+DOZ',
#  'WRB+IN',
#  'WRB+MD',
#  'WRB-HL',
#  'WRB-NC',
#  'WRB-TL',
#  '``']

# %% [markdown]
# __Exercis 15)__

# %%
# a)
# solution only considers common singular nouns in base form, using only one category for shorter run time
brown_tagged_words = brown.tagged_words(categories='news')
relevant_pairs = [pair for pair in brown_tagged_words if pair[1] in ['NN', 'NNS']]
fdist = nltk.FreqDist(relevant_pairs)
seen_words = []

# Add a new level of indentation to the following block
for pair in relevant_pairs:
  plural_pair = (pair[0] + 's', 'NNS')
  if pair[0] not in seen_words and pair[1] == 'NN' and plural_pair in relevant_pairs and fdist[pair[0]] < fdist[plural_pair]:
    print(pair[0], ': singular ', fdist[pair[0]], ', plural ', fdist[plural_pair])
    seen_words.append(pair[0])
# Out:
# investigation : singular  0 , plural  1
# election : singular  0 , plural  3
# place : singular  0 , plural  4
# charge : singular  0 , plural  9
# term : singular  0 , plural  7
# interest : singular  0 , plural  2
# number : singular  0 , plural  3
# end : singular  0 , plural  2
# cost : singular  0 , plural  17
# result : singular  0 , plural  3
# problem : singular  0 , plural  19
# title : singular  0 , plural  3
# law : singular  0 , plural  30
# date : singular  0 , plural  3
# program : singular  0 , plural  12
# state : singular  0 , plural  22
# exception : singular  0 , plural  2
# distribution : singular  0 , plural  1
# portion : singular  0 , plural  1
# court : singular  0 , plural  6
# fire : singular  0 , plural  2
# appointment : singular  0 , plural  2
# compensation : singular  0 , plural  1
# committee : singular  0 , plural  4
# fact : singular  0 , plural  1
# effect : singular  0 , plural  1
# management : singular  0 , plural  2
# purpose : singular  0 , plural  3
# doctor : singular  0 , plural  1
# night : singular  0 , plural  1
# jail : singular  0 , plural  1
# pension : singular  0 , plural  2
# plan : singular  0 , plural  15
# operation : singular  0 , plural  10
# suit : singular  0 , plural  4
# petition : singular  0 , plural  5
# couple : singular  0 , plural  2
# son : singular  0 , plural  4
# daughter : singular  0 , plural  5
# attorney : singular  0 , plural  5
# age : singular  0 , plural  2
# year : singular  0 , plural  101
# career : singular  0 , plural  3
# council : singular  0 , plural  1
# office : singular  0 , plural  4
# candidate : singular  0 , plural  10
# race : singular  0 , plural  1
# official : singular  0 , plural  12
# meeting : singular  0 , plural  5
# speaker : singular  0 , plural  2
# vote : singular  0 , plural  6
# crowd : singular  0 , plural  3
# cent : singular  0 , plural  4
# ballot : singular  0 , plural  1
# unit : singular  0 , plural  8
# system : singular  0 , plural  8
# director : singular  0 , plural  5
# time : singular  0 , plural  18
# session : singular  0 , plural  6
# highway : singular  0 , plural  3
# bond : singular  0 , plural  28
# afternoon : singular  0 , plural  1
# visit : singular  0 , plural  1
# issue : singular  0 , plural  9
# item : singular  0 , plural  4
# test : singular  0 , plural  3
# act : singular  0 , plural  7
# repair : singular  0 , plural  1
# work : singular  0 , plural  4
# source : singular  0 , plural  1
# road : singular  0 , plural  9
# department : singular  0 , plural  2
# fund : singular  0 , plural  27
# action : singular  0 , plural  6
# day : singular  0 , plural  37
# increase : singular  0 , plural  4
# expense : singular  0 , plural  7
# notice : singular  0 , plural  1
# privilege : singular  0 , plural  3
# word : singular  0 , plural  9
# amendment : singular  0 , plural  1
# legislator : singular  0 , plural  8
# aid : singular  0 , plural  1
# support : singular  0 , plural  1
# delegation : singular  0 , plural  1
# event : singular  0 , plural  4
# teacher : singular  0 , plural  7
# school : singular  0 , plural  36
# order : singular  0 , plural  7
# drop : singular  0 , plural  1
# trouble : singular  0 , plural  5
# phone : singular  0 , plural  1
# post : singular  0 , plural  5
# dispute : singular  0 , plural  2
# board : singular  0 , plural  3
# permit : singular  0 , plural  1
# gun : singular  0 , plural  2
# measure : singular  0 , plural  2
# hearing : singular  0 , plural  3
# week : singular  0 , plural  25
# passage : singular  0 , plural  1
# estimate : singular  0 , plural  3
# bank : singular  0 , plural  4
# bill : singular  0 , plural  16
# lawyer : singular  0 , plural  3
# sponsor : singular  0 , plural  1
# gift : singular  0 , plural  3
# debate : singular  0 , plural  2
# budget : singular  0 , plural  2
# horse : singular  0 , plural  1
# question : singular  0 , plural  8
# proposal : singular  0 , plural  9
# report : singular  0 , plural  9
# house : singular  0 , plural  6
# creation : singular  0 , plural  1
# dissent : singular  0 , plural  1
# district : singular  0 , plural  4
# site : singular  0 , plural  3
# revision : singular  0 , plural  1
# group : singular  0 , plural  12
# requirement : singular  0 , plural  4
# return : singular  0 , plural  1
# violation : singular  0 , plural  2
# fine : singular  0 , plural  1
# fee : singular  0 , plural  12
# license : singular  0 , plural  2
# right : singular  0 , plural  3
# need : singular  0 , plural  8
# lieutenant : singular  0 , plural  2
# justice : singular  0 , plural  1
# poll : singular  0 , plural  3
# kind : singular  0 , plural  1
# senator : singular  0 , plural  4
# idea : singular  0 , plural  5
# choice : singular  0 , plural  1
# water : singular  0 , plural  4
# development : singular  0 , plural  2
# effort : singular  0 , plural  22
# loan : singular  0 , plural  6
# project : singular  0 , plural  5
# attack : singular  0 , plural  4
# college : singular  0 , plural  9
# high : singular  0 , plural  1
# subject : singular  0 , plural  3
# person : singular  0 , plural  24
# team : singular  0 , plural  5
# professor : singular  0 , plural  1
# recommendation : singular  0 , plural  6
# employment : singular  0 , plural  1
# ribbon : singular  0 , plural  3
# firm : singular  0 , plural  15
# case : singular  0 , plural  17
# volume : singular  0 , plural  3
# color : singular  0 , plural  1
# trial : singular  0 , plural  1
# arrest : singular  0 , plural  2
# disclosure : singular  0 , plural  2
# client : singular  0 , plural  2
# request : singular  0 , plural  4
# honor : singular  0 , plural  5
# radio : singular  0 , plural  1
# home : singular  0 , plural  9
# way : singular  0 , plural  10
# completion : singular  0 , plural  3
# staff : singular  0 , plural  3
# minute : singular  0 , plural  25
# prosecution : singular  0 , plural  1
# matter : singular  0 , plural  3
# prosecutor : singular  0 , plural  2
# building : singular  0 , plural  5
# precinct : singular  0 , plural  4
# ward : singular  0 , plural  1
# procedure : singular  0 , plural  5
# room : singular  0 , plural  5
# abuse : singular  0 , plural  2
# function : singular  0 , plural  1
# judge : singular  0 , plural  5
# statement : singular  0 , plural  9
# hospital : singular  0 , plural  3
# railroad : singular  0 , plural  2
# retirement : singular  0 , plural  1
# worker : singular  0 , plural  15
# employer : singular  0 , plural  4
# base : singular  0 , plural  7
# boost : singular  0 , plural  1
# payment : singular  0 , plural  8
# patient : singular  0 , plural  1
# part : singular  0 , plural  6
# credit : singular  0 , plural  2
# service : singular  0 , plural  18
# stay : singular  0 , plural  1
# student : singular  0 , plural  21
# scholarship : singular  0 , plural  4
# government : singular  0 , plural  5
# grant : singular  0 , plural  13
# area : singular  0 , plural  12
# dollar : singular  0 , plural  15
# appropriation : singular  0 , plural  1
# sum : singular  0 , plural  1
# field : singular  0 , plural  1
# reaction : singular  0 , plural  1
# thing : singular  0 , plural  10
# pressure : singular  0 , plural  1
# chief : singular  0 , plural  1
# floor : singular  0 , plural  1
# record : singular  0 , plural  8
# leader : singular  0 , plural  22
# administrator : singular  0 , plural  1
# finance : singular  0 , plural  2
# cabinet : singular  0 , plural  1
# rank : singular  0 , plural  2
# rule : singular  0 , plural  10
# hour : singular  0 , plural  22
# demand : singular  0 , plural  5
# connection : singular  0 , plural  3
# element : singular  0 , plural  3
# organization : singular  0 , plural  3
# step : singular  0 , plural  8
# attempt : singular  0 , plural  3
# tension : singular  0 , plural  1
# advance : singular  0 , plural  1
# track : singular  0 , plural  1
# heart : singular  0 , plural  1
# line : singular  0 , plural  17
# disappointment : singular  0 , plural  1
# diplomat : singular  0 , plural  1
# danger : singular  0 , plural  2
# affair : singular  0 , plural  8
# impression : singular  0 , plural  1
# frame : singular  0 , plural  2
# mind : singular  0 , plural  1
# application : singular  0 , plural  4
# warning : singular  0 , plural  1
# setback : singular  0 , plural  1
# achievement : singular  0 , plural  1
# friction : singular  0 , plural  1
# consultation : singular  0 , plural  1
# use : singular  0 , plural  1
# method : singular  0 , plural  10
# conference : singular  0 , plural  5
# table : singular  0 , plural  2
# ground : singular  0 , plural  3
# control : singular  0 , plural  1
# chain : singular  0 , plural  1
# gain : singular  0 , plural  6
# situation : singular  0 , plural  2
# power : singular  0 , plural  1
# correspondent : singular  0 , plural  2
# direction : singular  0 , plural  1
# observer : singular  0 , plural  2
# response : singular  0 , plural  1
# reform : singular  0 , plural  4
# recipient : singular  0 , plural  2
# rate : singular  0 , plural  9
# war : singular  0 , plural  2
# neutralist : singular  0 , plural  1
# spirit : singular  0 , plural  1
# alternative : singular  0 , plural  1
# factor : singular  0 , plural  5
# nation : singular  0 , plural  12
# executive : singular  0 , plural  1
# trend : singular  0 , plural  2
# head : singular  0 , plural  2
# opinion : singular  0 , plural  3
# amount : singular  0 , plural  2
# job : singular  0 , plural  10
# advantage : singular  0 , plural  1
# vehicle : singular  0 , plural  1
# section : singular  0 , plural  1
# point : singular  0 , plural  10
# theater : singular  0 , plural  6
# level : singular  0 , plural  5
# move : singular  0 , plural  4
# form : singular  0 , plural  1
# letter : singular  0 , plural  12
# eye : singular  0 , plural  5
# benefit : singular  0 , plural  4
# list : singular  0 , plural  1
# chance : singular  0 , plural  3
# revenue : singular  0 , plural  13
# expert : singular  0 , plural  3
# luncheon : singular  0 , plural  1
# type : singular  0 , plural  4
# enterprise : singular  0 , plural  1
# voter : singular  0 , plural  12
# member : singular  0 , plural  69
# fellow : singular  0 , plural  1
# product : singular  0 , plural  16
# wage : singular  0 , plural  11
# profit : singular  0 , plural  2
# back : singular  0 , plural  1
# hand : singular  0 , plural  12
# suggestion : singular  0 , plural  3
# movement : singular  0 , plural  1
# goal : singular  0 , plural  4
# league : singular  0 , plural  3
# provision : singular  0 , plural  1
# minor : singular  0 , plural  1
# station : singular  0 , plural  2
# offense : singular  0 , plural  3
# remark : singular  0 , plural  2
# intention : singular  0 , plural  6
# merit : singular  0 , plural  2
# passenger : singular  0 , plural  3
# plant : singular  0 , plural  5
# position : singular  0 , plural  6
# taste : singular  0 , plural  1
# name : singular  0 , plural  6
# announcement : singular  0 , plural  2
# paper : singular  0 , plural  1
# commissioner : singular  0 , plural  3
# warden : singular  0 , plural  2
# tractor : singular  0 , plural  3
# bid : singular  0 , plural  3
# pledge : singular  0 , plural  1
# mouth : singular  0 , plural  1
# truth : singular  0 , plural  1
# partner : singular  0 , plural  1
# stop : singular  0 , plural  2
# good : singular  0 , plural  5
# stand : singular  0 , plural  2
# view : singular  0 , plural  5
# ticket : singular  0 , plural  5
# performance : singular  0 , plural  3
# discussion : singular  0 , plural  3
# struggle : singular  0 , plural  1
# successor : singular  0 , plural  1
# feeling : singular  0 , plural  1
# driver : singular  0 , plural  1
# visitor : singular  0 , plural  2
# reader : singular  0 , plural  1
# episode : singular  0 , plural  1
# stage : singular  0 , plural  3
# interview : singular  0 , plural  3
# month : singular  0 , plural  42
# hotel : singular  0 , plural  6
# owner : singular  0 , plural  10
# banker : singular  0 , plural  8
# role : singular  0 , plural  2
# panel : singular  0 , plural  5
# officer : singular  0 , plural  18
# economist : singular  0 , plural  1
# decision : singular  0 , plural  6
# joint : singular  0 , plural  2
# agreement : singular  0 , plural  5
# task : singular  0 , plural  2
# round : singular  0 , plural  3
# pace : singular  0 , plural  1
# manager : singular  0 , plural  8
# artist : singular  0 , plural  5
# street : singular  0 , plural  7
# course : singular  0 , plural  5
# car : singular  0 , plural  18
# center : singular  0 , plural  5
# union : singular  0 , plural  13
# reserve : singular  0 , plural  2
# stream : singular  0 , plural  1
# decade : singular  0 , plural  2
# seat : singular  0 , plural  4
# loyalist : singular  0 , plural  1
# picture : singular  0 , plural  3
# shortage : singular  0 , plural  1
# defeat : singular  0 , plural  1
# towel : singular  0 , plural  1
# sort : singular  0 , plural  1
# notion : singular  0 , plural  1
# conclusion : singular  0 , plural  1
# prospect : singular  0 , plural  7
# contract : singular  0 , plural  3
# signature : singular  0 , plural  5
# contractor : singular  0 , plural  2
# claim : singular  0 , plural  2
# headline : singular  0 , plural  1
# apartment : singular  0 , plural  6
# dog : singular  0 , plural  3
# animal : singular  0 , plural  1
# schedule : singular  0 , plural  3
# sentence : singular  0 , plural  1
# acre : singular  0 , plural  8
# tract : singular  0 , plural  1
# corporation : singular  0 , plural  2
# builder : singular  0 , plural  7
# planner : singular  0 , plural  1
# pedestrian : singular  0 , plural  2
# bomb : singular  0 , plural  1
# figure : singular  0 , plural  1
# representation : singular  0 , plural  1
# battalion : singular  0 , plural  1
# model : singular  0 , plural  2
# boy : singular  0 , plural  9
# bed : singular  0 , plural  3
# wall : singular  0 , plural  2
# front : singular  0 , plural  3
# wheel : singular  0 , plural  1
# critic : singular  0 , plural  1
# threat : singular  0 , plural  1
# graduate : singular  0 , plural  2
# father : singular  0 , plural  1
# structure : singular  0 , plural  2
# reason : singular  0 , plural  12
# total : singular  0 , plural  1
# game : singular  0 , plural  22
# workshop : singular  0 , plural  2
# dinner : singular  0 , plural  1
# face : singular  0 , plural  2
# belief : singular  0 , plural  3
# conduct : singular  0 , plural  1
# light : singular  0 , plural  2
# Attorney : singular  0 , plural  2
# defendant : singular  0 , plural  9
# top : singular  0 , plural  1
# hurler : singular  0 , plural  1
# contest : singular  0 , plural  1
# homer : singular  0 , plural  3
# solo : singular  0 , plural  1
# catcher : singular  0 , plural  1
# run : singular  0 , plural  30
# start : singular  0 , plural  6
# plate : singular  0 , plural  1
# fashion : singular  0 , plural  1
# club : singular  0 , plural  3
# appearance : singular  0 , plural  3
# triumph : singular  0 , plural  2
# double : singular  0 , plural  4
# inning : singular  0 , plural  3
# hole : singular  0 , plural  5
# shot : singular  0 , plural  4
# ball : singular  0 , plural  6
# error : singular  0 , plural  8
# blow : singular  0 , plural  1
# play : singular  0 , plural  3
# batter : singular  0 , plural  1
# scoreboard : singular  0 , plural  1
# hit : singular  0 , plural  11
# champion : singular  0 , plural  6
# average : singular  0 , plural  3
# squad : singular  0 , plural  1
# spectator : singular  0 , plural  5
# camp : singular  0 , plural  2
# surprise : singular  0 , plural  2
# rookie : singular  0 , plural  2
# farm : singular  0 , plural  3
# encounter : singular  0 , plural  1
# Pitcher : singular  0 , plural  1
# bat : singular  0 , plural  2
# flight : singular  0 , plural  1
# damage : singular  0 , plural  1
# wing : singular  0 , plural  1
# plane : singular  0 , plural  2
# condition : singular  0 , plural  7
# apprentice : singular  0 , plural  1
# allowance : singular  0 , plural  3
# duel : singular  0 , plural  1
# mark : singular  0 , plural  1
# season : singular  0 , plural  3
# second : singular  0 , plural  2
# quarterback : singular  0 , plural  1
# knee : singular  0 , plural  1
# halfback : singular  0 , plural  1
# nose : singular  0 , plural  1
# guard : singular  0 , plural  2
# string : singular  0 , plural  4
# senior : singular  0 , plural  1
# muscle : singular  0 , plural  1
# leg : singular  0 , plural  3
# practice : singular  0 , plural  6
# touchdown : singular  0 , plural  1
# yard : singular  0 , plural  22
# lot : singular  0 , plural  3
# film : singular  0 , plural  3
# rain : singular  0 , plural  1
# ankle : singular  0 , plural  2
# star : singular  0 , plural  1
# tactic : singular  0 , plural  1
# book : singular  0 , plural  12
# lefthander : singular  0 , plural  1
# arm : singular  0 , plural  8
# organ : singular  0 , plural  2
# dancer : singular  0 , plural  3
# sacrifice : singular  0 , plural  1
# baseball : singular  0 , plural  1
# train : singular  0 , plural  1
# trip : singular  0 , plural  3
# conductor : singular  0 , plural  1
# writer : singular  0 , plural  4
# grip : singular  0 , plural  2
# pitcher : singular  0 , plural  3
# player : singular  0 , plural  12
# guy : singular  0 , plural  1
# argument : singular  0 , plural  1
# fan : singular  0 , plural  3
# park : singular  0 , plural  3
# arrangement : singular  0 , plural  4
# feat : singular  0 , plural  1
# selection : singular  0 , plural  1
# championship : singular  0 , plural  1
# award : singular  0 , plural  4
# show : singular  0 , plural  3
# skit : singular  0 , plural  1
# dance : singular  0 , plural  1
# song : singular  0 , plural  1
# background : singular  0 , plural  1
# winner : singular  0 , plural  1
# raise : singular  0 , plural  3
# prize : singular  0 , plural  1
# duffer : singular  0 , plural  2
# human : singular  0 , plural  2
# sport : singular  0 , plural  6
# hope : singular  0 , plural  4
# golfer : singular  0 , plural  3
# par : singular  0 , plural  3
# fairway : singular  0 , plural  2
# dozen : singular  0 , plural  1
# pro : singular  0 , plural  1
# count : singular  0 , plural  2
# code : singular  0 , plural  1
# spot : singular  0 , plural  2
# green : singular  0 , plural  2
# force : singular  0 , plural  16
# stroke : singular  0 , plural  8
# tournament : singular  0 , plural  3
# margin : singular  0 , plural  1
# assignment : singular  0 , plural  2
# change : singular  0 , plural  10
# conversation : singular  0 , plural  2
# talk : singular  0 , plural  7
# junior : singular  0 , plural  2
# husband : singular  0 , plural  1
# tie : singular  0 , plural  2
# knock : singular  0 , plural  1
# slugger : singular  0 , plural  2
# hitter : singular  0 , plural  1
# bunter : singular  0 , plural  1
# kid : singular  0 , plural  5
# brother : singular  0 , plural  3
# marriage : singular  0 , plural  4
# holiday : singular  0 , plural  2
# occasion : singular  0 , plural  1
# sister : singular  0 , plural  3
# mother : singular  0 , plural  2
# evening : singular  0 , plural  1
# buffet : singular  0 , plural  1
# talent : singular  0 , plural  2
# instance : singular  0 , plural  2
# obstacle : singular  0 , plural  2
# representative : singular  0 , plural  5
# folk : singular  0 , plural  2
# engagement : singular  0 , plural  1
# girl : singular  0 , plural  6
# typewriter : singular  0 , plural  1
# pain : singular  0 , plural  2
# nerve : singular  0 , plural  2
# tour : singular  0 , plural  1
# movie : singular  0 , plural  4
# fur : singular  0 , plural  1
# slogan : singular  0 , plural  1
# uniform : singular  0 , plural  1
# smile : singular  0 , plural  1
# asset : singular  0 , plural  1
# civilian : singular  0 , plural  1
# sign : singular  0 , plural  3
# storm : singular  0 , plural  1
# motel : singular  0 , plural  4
# suite : singular  0 , plural  1
# tile : singular  0 , plural  1
# Honor : singular  0 , plural  1
# crown : singular  0 , plural  1
# maid : singular  0 , plural  1
# food : singular  0 , plural  2
# phase : singular  0 , plural  1
# display : singular  0 , plural  2
# bundle : singular  0 , plural  3
# contribution : singular  0 , plural  8
# shop : singular  0 , plural  1
# bridge : singular  0 , plural  2
# invitation : singular  0 , plural  2
# sale : singular  0 , plural  51
# sculpture : singular  0 , plural  3
# door : singular  0 , plural  5
# fund-raiser : singular  0 , plural  1
# restaurant : singular  0 , plural  1
# slipper : singular  0 , plural  1
# decline : singular  0 , plural  1
# cut : singular  0 , plural  4
# victim : singular  0 , plural  3
# store : singular  0 , plural  4
# mile : singular  0 , plural  10
# machine : singular  0 , plural  7
# plow : singular  0 , plural  1
# rifle : singular  0 , plural  2
# call : singular  0 , plural  7
# bedroom : singular  0 , plural  1
# resident : singular  0 , plural  6
# shelter : singular  0 , plural  1
# share : singular  0 , plural  19
# market : singular  0 , plural  1
# mortgage : singular  0 , plural  2
# consumer : singular  0 , plural  1
# submarine : singular  0 , plural  5
# sub : singular  0 , plural  1
# ring : singular  0 , plural  2
# reactor : singular  0 , plural  1
# friend : singular  0 , plural  11
# camera : singular  0 , plural  1
# dot : singular  0 , plural  1
# drawing : singular  0 , plural  1
# aunt : singular  0 , plural  1
# uncle : singular  0 , plural  1
# criminal : singular  0 , plural  1
# adviser : singular  0 , plural  7
# ship : singular  0 , plural  2
# design : singular  0 , plural  9
# missile : singular  0 , plural  3
# detail : singular  0 , plural  3
# indictment : singular  0 , plural  2
# narcotic : singular  0 , plural  6
# peddler : singular  0 , plural  1
# agent : singular  0 , plural  3
# bag : singular  0 , plural  2
# supervisor : singular  0 , plural  1
# youth : singular  0 , plural  4
# lover : singular  0 , plural  1
# relationship : singular  0 , plural  2
# neighbor : singular  0 , plural  6
# motion : singular  0 , plural  4
# deliberation : singular  0 , plural  1
# suburb : singular  0 , plural  1
# Principal : singular  0 , plural  1
# collection : singular  0 , plural  4
# Student : singular  0 , plural  2
# motorist : singular  0 , plural  3
# rebel : singular  0 , plural  3
# minister : singular  0 , plural  2
# appeal : singular  0 , plural  6
# tribunal : singular  0 , plural  1
# institution : singular  0 , plural  10
# newspaper : singular  0 , plural  2
# commitment : singular  0 , plural  3
# influence : singular  0 , plural  1
# obligation : singular  0 , plural  4
# mission : singular  0 , plural  1
# art : singular  0 , plural  3
# comment : singular  0 , plural  2
# mail : singular  0 , plural  3
# account : singular  0 , plural  2
# assault : singular  0 , plural  2
# guest : singular  0 , plural  14
# ant : singular  0 , plural  2
# chemical : singular  0 , plural  1
# path : singular  0 , plural  2
# conversion : singular  0 , plural  2
# moment : singular  0 , plural  1
# producer : singular  0 , plural  1
# dividend : singular  0 , plural  2
# investment : singular  0 , plural  1
# stock : singular  0 , plural  9
# adult : singular  0 , plural  3
# flower : singular  0 , plural  3
# male : singular  0 , plural  1
# female : singular  0 , plural  1
# bird : singular  0 , plural  4
# assessment : singular  0 , plural  1
# shoulder : singular  0 , plural  1
# stoppage : singular  0 , plural  1
# strike : singular  0 , plural  2
# chest : singular  0 , plural  1
# quota : singular  0 , plural  3
# heel : singular  0 , plural  1
# check : singular  0 , plural  2
# decoration : singular  0 , plural  2
# destroyer : singular  0 , plural  2
# crew : singular  0 , plural  1
# juror : singular  0 , plural  4
# farmer : singular  0 , plural  5
# incident : singular  0 , plural  1
# crop : singular  0 , plural  3
# rocket-bomb : singular  0 , plural  1
# bomber : singular  0 , plural  1
# engineer : singular  0 , plural  2
# mechanism : singular  0 , plural  2
# engine : singular  0 , plural  1
# pilot : singular  0 , plural  3
# operator : singular  0 , plural  2
# hoodlum : singular  0 , plural  2
# janitor : singular  0 , plural  2
# teamster : singular  0 , plural  4
# Government : singular  0 , plural  1
# price : singular  0 , plural  19
# underwriter : singular  0 , plural  2
# offering : singular  0 , plural  1
# combination : singular  0 , plural  1
# yield : singular  0 , plural  1
# run-up : singular  0 , plural  1
# merger : singular  0 , plural  2
# gin : singular  0 , plural  1
# manufacturer : singular  0 , plural  10
# percentage : singular  0 , plural  1
# maker : singular  0 , plural  1
# quarter : singular  0 , plural  2
# production : singular  0 , plural  1
# classroom : singular  0 , plural  1
# peak : singular  0 , plural  1
# improvement : singular  0 , plural  4
# lesson : singular  0 , plural  1
# rise : singular  0 , plural  1
# exchange : singular  0 , plural  2
# stockholder : singular  0 , plural  1
# shareholder : singular  0 , plural  2
# mistake : singular  0 , plural  2
# dealer : singular  0 , plural  10
# chair : singular  0 , plural  4
# competitor : singular  0 , plural  2
# picker : singular  0 , plural  3
# material : singular  0 , plural  3
# deduction : singular  0 , plural  2
# liquidation : singular  0 , plural  1
# taxpayer : singular  0 , plural  5
# province : singular  0 , plural  3
# parent : singular  0 , plural  4
# adjustment : singular  0 , plural  2
# low : singular  0 , plural  1
# standard : singular  0 , plural  4
# designer : singular  0 , plural  1
# shoe : singular  0 , plural  1
# piece : singular  0 , plural  7
# wrinkle : singular  0 , plural  1
# silhouette : singular  0 , plural  1
# white : singular  0 , plural  2
# tribe : singular  0 , plural  4
# shooting : singular  0 , plural  1
# steak : singular  0 , plural  1
# cafeteria : singular  0 , plural  1
# breast : singular  0 , plural  2
# variation : singular  0 , plural  1
# snack : singular  0 , plural  2
# poster : singular  0 , plural  2
# Design : singular  0 , plural  1
# wood : singular  0 , plural  4
# pool : singular  0 , plural  3
# rose : singular  0 , plural  1
# cookie : singular  0 , plural  3
# feature : singular  0 , plural  2
# concert : singular  0 , plural  6
# showing : singular  0 , plural  1
# residence : singular  0 , plural  1
# lamp : singular  0 , plural  1
# puppet : singular  0 , plural  5
# height : singular  0 , plural  2
# drum : singular  0 , plural  4
# shade : singular  0 , plural  2
# edge : singular  0 , plural  1
# decorator : singular  0 , plural  2
# pianist : singular  0 , plural  1
# draft : singular  0 , plural  2
# librarian : singular  0 , plural  4
# individual : singular  0 , plural  5
# major : singular  0 , plural  3
# Guest : singular  0 , plural  3
# ballet : singular  0 , plural  2
# aspect : singular  0 , plural  4
# virtue : singular  0 , plural  1
# character : singular  0 , plural  1
# peasant : singular  0 , plural  1
# toy : singular  0 , plural  4
# instrument : singular  0 , plural  1
# monument : singular  0 , plural  1
# language : singular  0 , plural  3
# cap : singular  0 , plural  1
# lighter : singular  0 , plural  1
# tank : singular  0 , plural  2
# chamber : singular  0 , plural  2
# painting : singular  0 , plural  5
# aide : singular  0 , plural  3
# poet : singular  0 , plural  1
# soldier : singular  0 , plural  2
# musician : singular  0 , plural  3
# confrontation : singular  0 , plural  1
# misunderstanding : singular  0 , plural  1
# negotiation : singular  0 , plural  11
# hat : singular  0 , plural  3
# principle : singular  0 , plural  2
# expectation : singular  0 , plural  1
# miracle : singular  0 , plural  1
# tone : singular  0 , plural  2
# employee : singular  0 , plural  11
# outsider : singular  0 , plural  2
# scholar : singular  0 , plural  1
# import : singular  0 , plural  3
# reservoir : singular  0 , plural  1
# communication : singular  0 , plural  1
# technique : singular  0 , plural  2
# implement : singular  0 , plural  3
# restriction : singular  0 , plural  3
# tool : singular  0 , plural  1
# antagonism : singular  0 , plural  1
# mechanic : singular  0 , plural  2
# signal : singular  0 , plural  1
# moral : singular  0 , plural  1
# extension : singular  0 , plural  1
# pretext : singular  0 , plural  1
# contrast : singular  0 , plural  1
# filibuster : singular  0 , plural  1
# modification : singular  0 , plural  1
# chore : singular  0 , plural  4
# sight : singular  0 , plural  1
# chapter : singular  0 , plural  1
# birdie : singular  0 , plural  2
# bogey : singular  0 , plural  1
# teammate : singular  0 , plural  2
# pinch-hitter : singular  0 , plural  1
# reporter : singular  0 , plural  4
# vow : singular  0 , plural  2
# mine : singular  0 , plural  3
# weapon : singular  0 , plural  6
# window : singular  0 , plural  1
# experiment : singular  0 , plural  1
# continent : singular  0 , plural  1
# roommate : singular  0 , plural  1
# enrollment : singular  0 , plural  1
# endowment : singular  0 , plural  2
# taking : singular  0 , plural  1
# stomach : singular  0 , plural  1
# slug : singular  0 , plural  1
# pocket : singular  0 , plural  2
# toll : singular  0 , plural  2
# investor : singular  0 , plural  7
# Indication : singular  0 , plural  1
# turnpike : singular  0 , plural  10
# textile : singular  0 , plural  5
# ton : singular  0 , plural  1
# co-op : singular  0 , plural  1
# truck : singular  0 , plural  6
# religion : singular  0 , plural  1
# resource : singular  0 , plural  6
# citizen : singular  0 , plural  6

# %%
import nltk
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# True

# %%
# b)
from collections import Counter
tagged_set = set(brown_tagged_words)
data = Counter(word for (word, tag) in tagged_set)
word_most_tags = data.most_common(1)[0][0]
for (word, tag) in tagged_set:
    if word == word_most_tags:
        print(tag)
        print(nltk.help.brown_tagset(tag))
        print('\n')
# Out:
# IN
# IN: preposition
#     of in for by considering to on among at through with under into
#     regarding than since despite according per before toward against as
#     after during including between without except upon out over ...
# None
#
#
# TO
# TO: infinitival to
#     to t'
# None
#
#
# NPS
# NPS: noun, plural, proper
#     Chases Aderholds Chapelles Armisteads Lockies Carbones French Marskmen
#     Toppers Franciscans Romans Cadillacs Masons Blacks Catholics British
#     Dixiecrats Mississippians Congresses ...
# None
#
#
# IN-TL
# No matching tags found.
# None
#
#
# IN-HL
# No matching tags found.
# None
#
#
# TO-HL
# No matching tags found.
# None

# %%
# c)
tags = [tag for (word, tag) in brown_tagged_words]
fdist = nltk.FreqDist(tags)
for (tag, count) in fdist.most_common(20):
    print(tag, ': ', count)
    print(nltk.help.brown_tagset(tag))
    print('\n')
# mostly open-class words: nouns, verbs
# Out:
# NN :  13162
# NN: noun, singular, common
#     failure burden court fire appointment awarding compensation Mayor
#     interim committee fact effect airport management surveillance jail
#     doctor intern extern night weekend duty legislation Tax Office ...
# None
#
#
# IN :  10616
# IN: preposition
#     of in for by considering to on among at through with under into
#     regarding than since despite according per before toward against as
#     after during including between without except upon out over ...
# None
#
#
# AT :  8893
# AT: article
#     the an no a every th' ever' ye
# None
#
#
# NP :  6866
# NP: noun, singular, proper
#     Fulton Atlanta September-October Durwood Pye Ivan Allen Jr. Jan.
#     Alpharetta Grady William B. Hartsfield Pearl Williams Aug. Berry J. M.
#     Cheshire Griffin Opelika Ala. E. Pelham Snodgrass ...
# None
#
#
# , :  5133
# ,: comma
#     ,
# None
#
#
# NNS :  5066
# NNS: noun, plural, common
#     irregularities presentments thanks reports voters laws legislators
#     years areas adjustments chambers $100 bonds courts sales details raises
#     sessions members congressmen votes polls calls ...
# None
#
#
# . :  4452
# .: sentence terminator
#     . ? ; ! :
# None
#
#
# JJ :  4392
# JJ: adjective
#     ecent over-all possible hard-fought favorable hard meager fit such
#     widespread outmoded inadequate ambiguous grand clerical effective
#     orderly federal foster general proportionate ...
# None
#
#
# CC :  2664
# CC: conjunction, coordinating
#     and or but plus & either neither nor yet 'n' and/or minus an'
# None
#
#
# VBD :  2524
# VBD: verb, past tense
#     said produced took recommended commented urged found added praised
#     charged listed became announced brought attended wanted voted defeated
#     received got stood shot scheduled feared promised made ...
# None
#
#
# NN-TL :  2486
# No matching tags found.
# None
#
#
# VB :  2440
# VB: verb, base: uninflected present, imperative or infinitive
#     investigate find act follow inure achieve reduce take remedy re-set
#     distribute realize disable feel receive continue place protect
#     eliminate elaborate work permit run enter force ...
# None
#
#
# VBN :  2269
# VBN: verb, past participle
#     conducted charged won received studied revised operated accepted
#     combined experienced recommended effected granted seen protected
#     adopted retarded notarized selected composed gotten printed ...
# None
#
#
# RB :  2166
# RB: adverb
#     only often generally also nevertheless upon together back newly no
#     likely meanwhile near then heavily there apparently yet outright fully
#     aside consistently specifically formally ever just ...
# None
#
#
# CD :  2020
# CD: numeral, cardinal
#     two one 1 four 2 1913 71 74 637 1937 8 five three million 87-31 29-5
#     seven 1,119 fifty-three 7.5 billion hundred 125,000 1,700 60 100 six
#     ...
# None
#
#
# CS :  1509
# CS: conjunction, subordinating
#     that as after whether before while like because if since for than altho
#     until so unless though providing once lest s'posin' till whereas
#     whereupon supposing tho' albeit then so's 'fore
# None
#
#
# VBG :  1398
# VBG: verb, present participle or gerund
#     modernizing improving purchasing Purchasing lacking enabling pricing
#     keeping getting picking entering voting warning making strengthening
#     setting neighboring attending participating moving ...
# None
#
#
# TO :  1237
# TO: infinitival to
#     to t'
# None
#
#
# PPS :  1056
# PPS: pronoun, personal, nominative, 3rd person singular
#     it he she thee
# None
#
#
# PP$ :  1051
# PP$: determiner, possessive
#     our its his their my your her out thy mine thine
# None

# %%
# d)
all_bigrams = list(nltk.bigrams(brown_tagged_words))
tags_before_nouns = [tag1 for ((word1, tag1), (word2, tag2)) in all_bigrams if tag2.startswith('N')]
fdist = nltk.FreqDist(tags_before_nouns)
for (tag, count) in fdist.most_common(20):
    print(tag, ': ', count)
    print(nltk.help.brown_tagset(tag))
    print('\n')
# Out:
# AT :  5969
# AT: article
#     the an no a every th' ever' ye
# None
#
#
# IN :  3328
# IN: preposition
#     of in for by considering to on among at through with under into
#     regarding than since despite according per before toward against as
#     after during including between without except upon out over ...
# None
#
#
# JJ :  3128
# JJ: adjective
#     ecent over-all possible hard-fought favorable hard meager fit such
#     widespread outmoded inadequate ambiguous grand clerical effective
#     orderly federal foster general proportionate ...
# None
#
#
# NP :  2977
# NP: noun, singular, proper
#     Fulton Atlanta September-October Durwood Pye Ivan Allen Jr. Jan.
#     Alpharetta Grady William B. Hartsfield Pearl Williams Aug. Berry J. M.
#     Cheshire Griffin Opelika Ala. E. Pelham Snodgrass ...
# None
#
#
# NN :  2367
# NN: noun, singular, common
#     failure burden court fire appointment awarding compensation Mayor
#     interim committee fact effect airport management surveillance jail
#     doctor intern extern night weekend duty legislation Tax Office ...
# None
#
#
# , :  1231
# ,: comma
#     ,
# None
#
#
# NN-TL :  1172
# No matching tags found.
# None
#
#
# . :  1106
# .: sentence terminator
#     . ? ; ! :
# None
#
#
# CC :  894
# CC: conjunction, coordinating
#     and or but plus & either neither nor yet 'n' and/or minus an'
# None
#
#
# CD :  841
# CD: numeral, cardinal
#     two one 1 four 2 1913 71 74 637 1937 8 five three million 87-31 29-5
#     seven 1,119 fifty-three 7.5 billion hundred 125,000 1,700 60 100 six
#     ...
# None
#
#
# PP$ :  739
# PP$: determiner, possessive
#     our its his their my your her out thy mine thine
# None
#
#
# JJ-TL :  626
# No matching tags found.
# None
#
#
# AP :  570
# AP: determiner/pronoun, post-determiner
#     many other next more last former little several enough most least only
#     very few fewer past same Last latter less single plenty 'nough lesser
#     certain various manye next-to-last particular final previous present
#     nuf
# None
#
#
# NP-TL :  523
# No matching tags found.
# None
#
#
# VBG :  422
# VBG: verb, present participle or gerund
#     modernizing improving purchasing Purchasing lacking enabling pricing
#     keeping getting picking entering voting warning making strengthening
#     setting neighboring attending participating moving ...
# None
#
#
# VBN :  357
# VBN: verb, past participle
#     conducted charged won received studied revised operated accepted
#     combined experienced recommended effected granted seen protected
#     adopted retarded notarized selected composed gotten printed ...
# None
#
#
# DT :  335
# DT: determiner/pronoun, singular
#     this each another that 'nother
# None
#
#
# VB :  332
# VB: verb, base: uninflected present, imperative or infinitive
#     investigate find act follow inure achieve reduce take remedy re-set
#     distribute realize disable feel receive continue place protect
#     eliminate elaborate work permit run enter force ...
# None
#
#
# VBD :  309
# VBD: verb, past tense
#     said produced took recommended commented urged found added praised
#     charged listed became announced brought attended wanted voted defeated
#     received got stood shot scheduled feared promised made ...
# None
#
#
# CS :  263
# CS: conjunction, subordinating
#     that as after whether before while like because if since for than altho
#     until so unless though providing once lest s'posin' till whereas
#     whereupon supposing tho' albeit then so's 'fore
# None

# %% [markdown]
# __Exercise 16)__
